# %%
import re
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
import urllib

import pandas as pd 
import numpy as np

import os
import warnings
from tqdm import tqdm
warnings.filterwarnings("ignore")

os.chdir("/Users/janechoi/Desktop/2020-CO-DEEP/preprocess crawl_12_05")

print(os.getcwd())

data00 = pd.read_csv('book_100000.csv')
data0 = pd.read_csv('book_110000.csv')
data01 = pd.read_csv('book_120000.csv')
data1 = pd.read_csv('book_130001_135000.csv')
data2 = pd.read_csv('book_135000_140000.csv')
data3 = pd.read_csv('book_140001_145000.csv')
data4 = pd.read_csv('book_145001_150000.csv')
data5 = pd.read_csv('book_150001_160000.csv')
data6 = pd.read_csv('book_160001_196940.csv')

data3.head()
# Out:
# /Users/janechoi/Desktop/2020-CO-DEEP/preprocess crawl_12_05
#      book_id img page    pub pub_year  \
# 0  EM0999845   Y  287  마음의 숲     2016
# 1  EM0992601   Y  174  꾸리에북스     2016
# 2  EM0828253   Y  216    그린비     2009
# 3  EE0443423   Y  300     이음     2011
# 4  EM0707567   Y  227    문음사    2004.
#
#                                       subject                     writer
# 0  나는 나로 살기로 했다 :냉담한 현실에서 어른살이를 위한 to do list                   김수현 글·그림
# 1            모든 사람은 혼자다 :결혼한 독신녀 보부아르의 장편 에세이       시몬 드 보부아르 지음 ;박정자 옮김
# 2                    굿바이 다윈? :신다윈주의, 비판적으로 읽기  이케다 기요히코(池田淸彦) 지음 ;박성관 옮김
# 3                                   사회생물학 대논쟁           김동광, 김세균, 최재천 엮음
# 4                               (국가가 필요없는) 교육         제임스 툴리 지음 ;손준종 옮김.

# %% [markdown]
# ### 1. 여기 데이터 고쳐야 됩니다!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
#CONCAT DATA AND SELECT NEEDED 


def concat_data():
    data = pd.concat([data00,data0,data01,data1,data2,data3,data4,data5,data6],axis=0)

    data = data[['book_id','img','pub_year','subject','page']]

    return data


data =concat_data()
data.head(20)
data.isnull().sum()
# Out:
# book_id         0
# img             0
# pub_year     5873
# subject      2381
# page        15662
# dtype: int64

# %%
data.head(60)
# Out:
#       book_id img pub_year                                            subject  \
# 0   EE0295062   Y    2003.              (쇼펜하우어의) 토론의 법칙 :논쟁과 토론에서 이기는 38가지 기술
# 1   EM0970277   Y     2015           그 사람이 나를 도와주는 진짜 이유 :전문가가 읽어주는 아들러 실전심리학
# 2   EM0970083   Y     2015                   아들러 심리학 입문 :오늘을 살아가는 무기, 용기의 심리학
# 3   EM0557577   Y     2001                                    마이너리그 :은희경 장편소설
# 4   EE0426996   Y    2011.                                       조경디자인 그래픽랭귀지
# 5   EE0429658   Y    2011.                                            조경기초디자인
# 6   EE0442934   Y     2011                                어떤 작위의 세계 :정영문 장편소설
# 7   EE0447671   Y     2013             땅심 살리는 퇴비 만들기 :석종욱이 들려주는 내 땅 살리는 퇴비제조법
# 8   EM0914862   Y     2013                                          IFRS 중급회계
# 9   EE0370688   Y    2007.                              유기농업 :참먹거리 생산의 이론과 기술
# 10  EM0912722   Y     2013                                (IFRS) 중급회계 :연습문제해답
# 11  EE0265015   N    2000.                                            작물재배학원론
# 12  EM0904891   Y     2012              조선을 떠나며 :1945년 패전을 맞은 일본인들의 최후 :역사논픽션
# 13  EM0866814   Y    2010.                           할리우드 시크릿 :미국을 읽는 70가지 방법
# 14  EM0861795   Y    2008.                              미국의 정치문화, 기독교, 그리고 영화
# 15  EM0803185   Y    2008.                                         영화로 본 미국문화
# 16  EE0428941   N    2011.                                       (제4판)사료자원핸드북
# 17  EE0391459   N    2007.  (한국사양표준)한우 =Korean feeding standard for Hanwoo...
# 18  EE0428940   N    2011.                                       (제4판)사료자원핸드북
# 19  EE0468258   Y     2015                      사회 정의란 무엇인가 :현대 정의 이론과 공동선 탐구
# 20  EE0431230   Y     2011  형평과 정의 :조화로운 사회적 삶의 원리를 찾아서 =Equity and justic...
# 21  EM0834546   Y    2009.                                        명탐정 홈즈걸의 책장
# 22  EE0455714   Y     2014                  (알기 쉬운) 자동차 기관 =Automobile engine
# 23  EM0888160   Y    2012.                                 번역의 이해 :영한번역을 중심으로
# 24  EE0424603   N    1981-                                          농촌지도사업보고서
# 25  EE0464349   N    1997-                                        주요 농산물 유통실태
# 26  EM0561638   Y    2000.                      수학 100의 정리 :피타고라스 정리부터 현대수학까지
# 27  EE0471099   Y     2015                                       출산, 그 놀라운 역사
# 28  EM0713502   Y     2006     당신들의 대한민국.&nbsp;2, 한국학 교수 박노자가 말하는 '주식회사' 대한민국
# 29  EM0773029   Y    2007.                                        맛보기 전엔 죽지마라
# 30  EM0923538   Y     2013                                   400일간의 김치버스 세계일주
# 31  EE0470113   Y     2014                  (좋은 사진을 만드는 ZAKO의) 미러리스 사진 잘 찍는 법
# 32  EE0410201   Y    2009.                            (독학으로)VC++ :진정한 프로그램 중심
# 33  EE0394361   Y     2008                               (IQ 148을 위한) 멘사논리스페셜
# 34  EM0292952   Y    1991.                               封印된 時間 :영화예술의 미학과 시학
# 35  EM0477213   Y    1998.                                 외로우니까 사람이다: 정호승 시집
# 36  EM0648149   Y    2000.                                               부끄러움
# 37  EE0439836   Y     2010                                      선형대수학 express
# 38  EE0440363   Y     2012                         (500년 무역 대국) 부(富)의 도시 베네치아
# 39  EM0916337   Y     2012                  (만들면서 배우는) 기계 학습 :생각을 만드는 빅데이터 기술
# 40  EM0966001   Y     2014                    (빅데이터 시대를 여는 첫걸음) NoSQL 데이터 모델링
# 41  EE0362566   Y    2006.                          (마음의 평안과 자유를 얻은) 30년만의 휴식
# 42  EM0971864   Y     2015              머신 러닝 인 파이썬 :파이썬을 활용한, 예측분석을 위한 기계 학습
# 43  EM0971882   Y     2015                            (그림 한 장으로 보는) 최신 IT 트렌드
# 44  EM0812923   Y    2008.    사랑하지만, 사랑하지 않는다 :나…… 사랑하나요? 당신에게만 묻고 싶은 마음속 한마디
# 45  EE0443958   Y     2012                                        (스마트) 물리학개론
# 46  EM0487466   Y     1998                                          인간 자유의 본질
# 47  EM0437487   N    1997.                                    아라비안 나이트 :하일지 판
# 48  EM0437484   N    1997.                                    아라비안 나이트 :하일지 판
# 49  EM0479883   N    1995.                     하이트로 바꾼 기업운명 :생생한 맥주 마케팅 전쟁사례
# 50  EM0560876   Y    2001.                               (박카스 40년)그 신화와 광고이야기
# 51  EE0223431   Y    2000.                                      (新)자동차 가솔린 엔진
# 52  EE0238305   Y    2000.                                            자동차환경개론
# 53  EM0568944   Y    2001.                                           니체 다시 읽기
# 54  EM0827020   Y    2008.                            교실 속 갈등상황 100問 101答 :중등
# 55  EM0607340   Y    2002.       프랑스어로 말하기 :발음·문법·단어·동사정리 =Parler en français
# 56  EE0454940   Y     2013                                    여기에 시체를 버리지 마세요
# 57  EE0454938   Y     2013                                   교환살인에는 어울리지 않는 밤
# 58  EE0454970   Y     2014                                        웬수같은 이웃집 탐정
# 59  EM0850590   Y    2010.                                                NaN
#
#                page
# 0               136
# 1               186
# 2               NaN
# 3               250
# 4               183
# 5               207
# 6               294
# 7               259
# 8               NaN
# 9               330
# 10              NaN
# 11          vi, 393
# 12              296
# 13              468
# 14              282
# 15              214
# 16              NaN
# 17        xiii, 158
# 18              NaN
# 19              849
# 20              325
# 21              287
# 22              458
# 23         xii, 220
# 24     책 :삽화 ;26 cm
# 25  책 :삽화, 표 ;26 cm
# 26              NaN
# 27              504
# 28              319
# 29              295
# 30              368
# 31              NaN
# 32              500
# 33              NaN
# 34              309
# 35              116
# 36              106
# 37              502
# 38              556
# 39              228
# 40          ix, 280
# 41              286
# 42       xviii, 348
# 43              224
# 44              245
# 45              NaN
# 46              158
# 47              289
# 48              289
# 49              276
# 50              316
# 51              463
# 52         xii, 378
# 53              255
# 54              175
# 55              161
# 56              359
# 57              398
# 58              299
# 59              NaN

# %%
#CLEAN PUB YEAR 

def clean_pub_year(x):
    
    try: 
        float(x)
        return float(x)
    
    except:
#         print(x)
        r = list(x)        
        s=''
        for i in r:
            if i.isdigit():
                s+=str(i)
            else:
                pass
            
        #for years which have duration 
#         print(s)
        s = s[:4]
    
        #for misinfo 
        if s == '':
            return np.nan 
        else:
            return float(s)
                
        

data['pub_year'] = data['pub_year'].apply(lambda x: clean_pub_year(x))
        
# clean_pub_year('ad')

# %%
#CLEAN PAGE NUMS 

#'cm 포함 == 페이지 수 틀림 '
# data.loc[data['book_id'] == 'EE0316889','page'] =736
# data.loc[data['book_id'] == 'EE0316889','page'] 

def clean_page(x):
    try: 
        float(x)
        return float(x)
    
    except: 
        if 'cm' in x: 
#             print('cm in x', str(x))
            return np.nan
        else:
            if ',' in x:
#                 print(x)
                try:
                    return float(x.split(',')[-1])
                except:
                    return np.nan
                
            elif ';' in x:
#                 print(x)
                try:
                    return float(x.split(';')[-1])
                except:
                    return np.nan
                
        
# clean_page('xi,529')


data['page'] = data['page'].apply(lambda x: clean_page(x))

# data.tail()

# %%
def clean_column(data):
    data['page'] = data['page'].apply(lambda x: clean_page(x))
    data['pub_year'] = data['pub_year'].apply(lambda x: clean_pub_year(x))
    return data 

data = clean_column(data)
    
data.head(20)
# Out:
#       book_id img  pub_year  \
# 0   EE0295062   Y    2003.0
# 1   EM0970277   Y    2015.0
# 2   EM0970083   Y    2015.0
# 3   EM0557577   Y    2001.0
# 4   EE0426996   Y    2011.0
# 5   EE0429658   Y    2011.0
# 6   EE0442934   Y    2011.0
# 7   EE0447671   Y    2013.0
# 8   EM0914862   Y    2013.0
# 9   EE0370688   Y    2007.0
# 10  EM0912722   Y    2013.0
# 11  EE0265015   N    2000.0
# 12  EM0904891   Y    2012.0
# 13  EM0866814   Y    2010.0
# 14  EM0861795   Y    2008.0
# 15  EM0803185   Y    2008.0
# 16  EE0428941   N    2011.0
# 17  EE0391459   N    2007.0
# 18  EE0428940   N    2011.0
# 19  EE0468258   Y    2015.0
#
#                                               subject   page
# 0               (쇼펜하우어의) 토론의 법칙 :논쟁과 토론에서 이기는 38가지 기술  136.0
# 1            그 사람이 나를 도와주는 진짜 이유 :전문가가 읽어주는 아들러 실전심리학  186.0
# 2                    아들러 심리학 입문 :오늘을 살아가는 무기, 용기의 심리학    NaN
# 3                                     마이너리그 :은희경 장편소설  250.0
# 4                                        조경디자인 그래픽랭귀지  183.0
# 5                                             조경기초디자인  207.0
# 6                                 어떤 작위의 세계 :정영문 장편소설  294.0
# 7              땅심 살리는 퇴비 만들기 :석종욱이 들려주는 내 땅 살리는 퇴비제조법  259.0
# 8                                           IFRS 중급회계    NaN
# 9                               유기농업 :참먹거리 생산의 이론과 기술  330.0
# 10                                (IFRS) 중급회계 :연습문제해답    NaN
# 11                                            작물재배학원론  393.0
# 12              조선을 떠나며 :1945년 패전을 맞은 일본인들의 최후 :역사논픽션  296.0
# 13                           할리우드 시크릿 :미국을 읽는 70가지 방법  468.0
# 14                              미국의 정치문화, 기독교, 그리고 영화  282.0
# 15                                         영화로 본 미국문화  214.0
# 16                                       (제4판)사료자원핸드북    NaN
# 17  (한국사양표준)한우 =Korean feeding standard for Hanwoo...  158.0
# 18                                       (제4판)사료자원핸드북    NaN
# 19                      사회 정의란 무엇인가 :현대 정의 이론과 공동선 탐구  849.0

# %%
#SELECT NEW INFO WE NEED TO CRAWL 

info_need = data[(data['img']=='N') | (data['pub_year'].isnull())
                 |(data['subject'].isnull()) | (data['page'].isnull())]

books = info_need['book_id'].unique()
# books[:10]
len(books) #30276
# Out:
# 30276

# %%
def select_new(data):
    info_need = data[(data['img']=='N') | (data['pub_year'].isnull())
                 |(data['subject'].isnull()) | (data['page'].isnull())]
    
    new_data = data[(data['img']!='N') & (data['pub_year'].notnull())
                 &(data['subject'].notnull()) & (data['page'].notnull())]
    
    books = info_need['book_id'].unique()
    return info_need, new_data, books

# %%
#delete the books according to id

# %% [markdown]
# ### 위에, 자기 데이터에 맞게 고치고, 그외엔 함수만 실행해도 되고, 이거 실행 시키묜 댄다!!!!!!!!!!!!!!!!!!!!

# %%
##PREPROCESS TOTAL 
data =concat_data()
data = clean_column(data)
new, newdata, books = select_new(data)
len(books) #30276
# newdata.isnull().sum()
newdata.shape #(45999, 5)
new.head(10)
# newdata.to_csv('book_100000_196940.csv', index=0)
data.shape #(96937, 5)
# Out:
# (96937, 5)

# %%
new[545:]
# Out:
#          book_id img  pub_year  \
# 1431   EM0945159   N       NaN
# 1432   EE0465682   Y    2013.0
# 1433   EE0274908   N    1996.0
# 1443   EM0964094   Y    2015.0
# 1445   EM0883257   Y    2011.0
# ...          ...  ..       ...
# 36923  EM1012580   Y       NaN
# 36924  EM0666036   Y    2017.0
# 36926  EM1015146   N       NaN
# 36927  EM0688769   Y    2017.0
# 36932  EM1020509   Y    2014.0
#
#                                                  subject   page
# 1431                                                 NaN    NaN
# 1432                                     나의 문화유산답사기 :일본편    NaN
# 1433                                                일반역학  345.0
# 1443           근대문화사 :흑사병에서 1차 세계대전에 이르기까지 유럽 영혼이 직면한 위기    NaN
# 1445                              헌법의 풍경 :잃어버린 헌법을 위한 변론    NaN
# ...                                                  ...    ...
# 36923                              Arirang korean basics    NaN
# 36924                        (회사에서 맨날 쓰는) 비즈니스 영어패턴 500+    NaN
# 36926  South Korea's demographic dividend :echoes of ...    NaN
# 36927                                 형법요론 =Criminal law    NaN
# 36932                                         여행이 좋아, 파리    NaN
#
# [29731 rows x 5 columns]

# %%
bookdb_new= pd.read_csv('new_books_END.csv')
bookdb_new.shape
# Out:
# (8000, 5)

# %%
#NEW CRAWLING
import time
# bookdb_new = pd.DataFrame()
    
driver = webdriver.Chrome('/Users/janechoi/Desktop/2020-CO-DEEP/crawling-12/chromedriver') 

driver.implicitly_wait(3)
    
for i in tqdm(range(8000,10000)):
    try:
        time.sleep(1)
        book_id = books[i]
    
        url = "https://lib.skku.edu/#/search/total/si?all=1%7Ck%7Ca%7C{}".format(book_id)
        driver.get(url)
    
    
        result = driver.find_element_by_xpath('/html/body/div[1]/div[2]/div[2]/div/div[2]/div[2]/div[3]/div/ik-total-search[1]/div/div[2]/div/div[2]/ul/li[1]/a[2]')
        result.click()
    
        driver.switch_to.window(driver.window_handles[1])
    
    #open the detailed info 
        try:
            driver.find_element_by_css_selector('#btn-biblio-more-open').click()
        except: 
            pass

    
    #image retreival 
        book_cover = driver.find_elements_by_css_selector('div.ikc-bookcover')
        img_url = re.findall('(?<=src=").+?(?=")', book_cover[0].get_attribute('outerHTML'))[0]
    
        try :
            img_name = 'cover/' + book_id + '.jpg'
            urllib.request.urlretrieve(img_url,img_name)
            img = 'Y'
        
        except:
            img = 'N'
    
    
    
    ##book title 
        book_title = driver.find_element_by_css_selector('body > div.ikc-pyxis-wrap > div.ikc-container-wrap > div.ikc-container > div > div.ikc-main.kku-search > div.kku-main > div:nth-child(2) > div > div.ikc-search-detail-main > div > div.ikc-biblio-detail > div.ikc-biblio-info > ul > li:nth-child(1) > span').text

        title = book_title.split('/')[0]
    
        for i in range(3,9):
            try:
                text= driver.find_element_by_css_selector('body > div.ikc-pyxis-wrap > div.ikc-container-wrap > div.ikc-container > div > div.ikc-main.kku-search > div.kku-main > div:nth-child(2) > div > div.ikc-search-detail-main > div > div.ikc-biblio-detail > div.ikc-biblio-info > ul > li:nth-child('+str(i)+') > label').text
       
        ##book pub year 
                if text == '발행사항':
                    book_pub= driver.find_element_by_css_selector('body > div.ikc-pyxis-wrap > div.ikc-container-wrap > div.ikc-container > div > div.ikc-main.kku-search > div.kku-main > div:nth-child(2) > div > div.ikc-search-detail-main > div > div.ikc-biblio-detail > div.ikc-biblio-info > ul > li:nth-child('+str(i)+') > span > span').text
                
                    pubyear= book_pub.split(',')[-1]
#                 print(pubyear)
        
        ## book page 
                elif text == '형태사항':
                    book_page= driver.find_element_by_css_selector('body > div.ikc-pyxis-wrap > div.ikc-container-wrap > div.ikc-container > div > div.ikc-main.kku-search > div.kku-main > div:nth-child(2) > div > div.ikc-search-detail-main > div > div.ikc-biblio-detail > div.ikc-biblio-info > ul > li:nth-child('+str(i)+') > span > span').text
                
                    page= book_page.split(' p.')[0]
#                 print(page)
    
                else: 
                    pass
            except:
                break
    
        if pubyear == None: 
            pubyear= np.nan
    
        if page == None:
            page = np.nan
    
        bookdb_new = bookdb_new.append({"book_id" : book_id, "subject" : title, "pub_year" : pubyear, 
    
                                        "page" : page, 'img' : img}, ignore_index=True)
        driver.close()
        driver.switch_to_window(driver.window_handles[0])
    
    except:
        bookdb_new =bookdb_new.append({"book_id" : book_id, 'subject' : 'notfound'
                                       ,'pub_year' : 'notfound', 'page': 'notfound',
                                      'img':'notfound'}, ignore_index=True)
        
    
    
    bookdb_new.to_csv('new_books_jinhang.csv', index = False)
# Out:
# 100%|██████████| 3000/3000 [2:53:32<00:00,  3.47s/it]

# %%
bookdb_new.tail()
# bookdb_new.shape
# Out:
#         book_id img      page pub_year  \
# 7995  EM0978737   Y   100, 39   [2014]
# 7996  WM0204125   Y  xix, 421   c2005.
# 7997  EM0785103   Y       362    2006.
# 7998  WM0267989   N        61   c2015.
# 7999  WM0265525   N       344   c2015.
#
#                                                 subject
# 7995  SPSS Statistics 비모수적 방법과 붓스트랩 방법 =SPSS statist...
# 7996                             Economics for lawyers
# 7997                                          음향시스템핸드북
# 7998  Thing explainer :complicated stuff in simple w...
# 7999                                      Rogue lawyer

# %%
# new[new['subject'].isnull()]
new.head(10)
# Out:
#       book_id img  pub_year  \
# 2   EM0970083   Y    2015.0
# 8   EM0914862   Y    2013.0
# 10  EM0912722   Y    2013.0
# 11  EE0265015   N    2000.0
# 16  EE0428941   N    2011.0
# 17  EE0391459   N    2007.0
# 18  EE0428940   N    2011.0
# 24  EE0424603   N    1981.0
# 25  EE0464349   N    1997.0
# 26  EM0561638   Y    2000.0
#
#                                               subject   page
# 2                    아들러 심리학 입문 :오늘을 살아가는 무기, 용기의 심리학    NaN
# 8                                           IFRS 중급회계    NaN
# 10                                (IFRS) 중급회계 :연습문제해답    NaN
# 11                                            작물재배학원론  393.0
# 16                                       (제4판)사료자원핸드북    NaN
# 17  (한국사양표준)한우 =Korean feeding standard for Hanwoo...  158.0
# 18                                       (제4판)사료자원핸드북    NaN
# 24                                          농촌지도사업보고서    NaN
# 25                                        주요 농산물 유통실태    NaN
# 26                      수학 100의 정리 :피타고라스 정리부터 현대수학까지    NaN

# %%
bookdb_new.to_csv('new_books_END.csv', index = False)

# %%
book  = pd.read_csv('book_100000_196940.csv')
# book.head(20)
# Out:
#       book_id img  pub_year  \
# 0   EE0295062   Y    2003.0
# 1   EM0970277   Y    2015.0
# 2   EM0557577   Y    2001.0
# 3   EE0426996   Y    2011.0
# 4   EE0429658   Y    2011.0
# 5   EE0442934   Y    2011.0
# 6   EE0447671   Y    2013.0
# 7   EE0370688   Y    2007.0
# 8   EM0904891   Y    2012.0
# 9   EM0866814   Y    2010.0
# 10  EM0861795   Y    2008.0
# 11  EM0803185   Y    2008.0
# 12  EE0468258   Y    2015.0
# 13  EE0431230   Y    2011.0
# 14  EM0834546   Y    2009.0
# 15  EE0455714   Y    2014.0
# 16  EM0888160   Y    2012.0
# 17  EE0471099   Y    2015.0
# 18  EM0713502   Y    2006.0
# 19  EM0773029   Y    2007.0
#
#                                               subject   page
# 0               (쇼펜하우어의) 토론의 법칙 :논쟁과 토론에서 이기는 38가지 기술  136.0
# 1            그 사람이 나를 도와주는 진짜 이유 :전문가가 읽어주는 아들러 실전심리학  186.0
# 2                                     마이너리그 :은희경 장편소설  250.0
# 3                                        조경디자인 그래픽랭귀지  183.0
# 4                                             조경기초디자인  207.0
# 5                                 어떤 작위의 세계 :정영문 장편소설  294.0
# 6              땅심 살리는 퇴비 만들기 :석종욱이 들려주는 내 땅 살리는 퇴비제조법  259.0
# 7                               유기농업 :참먹거리 생산의 이론과 기술  330.0
# 8               조선을 떠나며 :1945년 패전을 맞은 일본인들의 최후 :역사논픽션  296.0
# 9                            할리우드 시크릿 :미국을 읽는 70가지 방법  468.0
# 10                              미국의 정치문화, 기독교, 그리고 영화  282.0
# 11                                         영화로 본 미국문화  214.0
# 12                      사회 정의란 무엇인가 :현대 정의 이론과 공동선 탐구  849.0
# 13  형평과 정의 :조화로운 사회적 삶의 원리를 찾아서 =Equity and justic...  325.0
# 14                                        명탐정 홈즈걸의 책장  287.0
# 15                  (알기 쉬운) 자동차 기관 =Automobile engine  458.0
# 16                                 번역의 이해 :영한번역을 중심으로  220.0
# 17                                       출산, 그 놀라운 역사  504.0
# 18     당신들의 대한민국.&nbsp;2, 한국학 교수 박노자가 말하는 '주식회사' 대한민국  319.0
# 19                                        맛보기 전엔 죽지마라  295.0
